# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('sales_data.csv')

total_revenue = data.groupby('product_id')['revenue'].sum().sort_values(ascending=False)

top_products = total_revenue.head(10)

plt.figure(figsize=(10, 6))
top_products.plot(kind='bar')
plt.title('Top 10 Products by Revenue')
plt.xlabel('Product ID')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Only 3 products are shown (and not 10 products) as the dataset contains info of these 3 distinct product IDs only.
print(top_products)
# Out:
# product_id
# 1002    360.0
# 1001    330.0
# 1003    270.0
# Name: revenue, dtype: float64
