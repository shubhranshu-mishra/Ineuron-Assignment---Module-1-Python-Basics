# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df.drop("Patient ID",axis=1,inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
 
from warnings import filterwarnings

# %%
sns.set_style('whitegrid')
sns.distplot(df[ ' Blood Pressure Before (mmHg)'], color ='red',bins=10)
# Out:
# /tmp/ipykernel_2293/2818568327.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[ ' Blood Pressure Before (mmHg)'], color ='red',bins=10)
# <AxesSubplot: xlabel=' Blood Pressure Before (mmHg)', ylabel='Density'>

# %%
sns.set_style('whitegrid')
sns.distplot(df[ ' Blood Pressure After (mmHg)'], color ='red',bins=10)
# Out:
# /tmp/ipykernel_2293/255891038.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[ ' Blood Pressure After (mmHg)'], color ='red',bins=10)
# <AxesSubplot: xlabel=' Blood Pressure After (mmHg)', ylabel='Density'>
